# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig,ax = plt.subplots(nrows=1,ncols=2) # 一行两列
ax[0].plot([1,2,3],[4,5,6]) # plot，用来绘制折线图
ax[1].scatter([1,2,3],[4,5,6]) # scatter，绘制散点图
plt.show()
