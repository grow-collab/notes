# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

plt.bar(['Java','Python','Go'],[1000,500,200]) # bar 柱状图
plt.title('月度人数')
plt.xlabel('课程')
plt.ylabel('人数')
plt.show()
